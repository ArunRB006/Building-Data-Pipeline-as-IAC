# %%
pip install boto3
# Out:
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (1.21.38)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3) (1.0.0)
# Requirement already satisfied: botocore<1.25.0,>=1.24.38 in /usr/local/lib/python3.7/dist-packages (from boto3) (1.24.38)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3) (0.5.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.25.0,>=1.24.38->boto3) (1.26.9)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.25.0,>=1.24.38->boto3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.25.0,>=1.24.38->boto3) (1.15.0)

# %%
import boto3
import pandas as pd
import psycopg2
import json
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
import configparser
config = configparser.ConfigParser()
config.read_file(open('/content/cluster.config'))

# %%
config.get("AWS","KEY")
# Out:
# 'AKIAUXMIT4ADRBM5TWIA'

# %%
KEY                        = config.get("AWS","KEY")
SECRET                     = config.get("AWS","SECRET")

DWH_CLUSTER_TYPE           = config.get("DWH","DWH_CLUSTER_TYPE")
DWH_NUM_NODES              = config.get("DWH","DWH_NUM_NODES")
DWH_NODE_TYPE              = config.get("DWH","DWH_NODE_TYPE")
DWH_CLUSTER_IDENTIFIER     = config.get("DWH","DWH_CLUSTER_IDENTIFIER")
DWH_DB                     = config.get("DWH","DWH_DB")
DWH_DB_USER                = config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD            = config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT                   = config.get("DWH","DWH_PORT")

DWH_IAM_ROLE_NAME          = config.get("DWH","DWH_IAM_ROLE_NAME")

(DWH_DB_USER, DWH_DB_PASSWORD, DWH_DB)
# Out:
# ('awsuser', 'Arun0006', 'dev')

# %%
pd.DataFrame({"Param":
              ["DWH_CLUSTER_TYPE","DWH_NUM_NODES", "DWH_NODE_TYPE", "DWH_CLUSTER_IDENTIFIER", "DWH_DB", "DWH_DB_USER", "DWH_DB_PASSWORD ", "DWH_PORT","DWH_IAM_ROLE_NAME"],
              "Value":
              [DWH_CLUSTER_TYPE,DWH_NUM_NODES, DWH_NODE_TYPE, DWH_CLUSTER_IDENTIFIER, DWH_DB, DWH_DB_USER, DWH_DB_PASSWORD, DWH_PORT,DWH_IAM_ROLE_NAME]
              })
# Out:
#                     Param               Value
# 0        DWH_CLUSTER_TYPE         single-node
# 1           DWH_NUM_NODES                   1
# 2           DWH_NODE_TYPE           dc2.large
# 3  DWH_CLUSTER_IDENTIFIER   my-first-redshift
# 4                  DWH_DB                 dev
# 5             DWH_DB_USER             awsuser
# 6        DWH_DB_PASSWORD             Arun0006
# 7                DWH_PORT                5439
# 8       DWH_IAM_ROLE_NAME  redshift-s3-access

# %%
ec2 = boto3.resource('ec2',
                     region_name="ap-south-1",
                     aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET
                     )

# %%
s3 = boto3.resource('s3',
                     region_name="ap-south-1",
                     aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET
                     )
iam = boto3.client('iam',
                     region_name="ap-south-1",
                     aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET
                     )
redshift = boto3.client('redshift',
                     region_name="ap-south-1",
                     aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET
                     )

# %%
bucket=s3.Bucket("arun-test-bucket-global")
log_data_files = [filename.key for filename in bucket.objects.filter(Prefix='')]  
log_data_files
# Out:
# ['allevents_pipe.txt',
#  'allusers_pipe.txt',
#  'category_pipe.txt',
#  'date2008_pipe.txt',
#  'listings_pipe.txt',
#  'sales_tab.txt',
#  'venue_pipe.txt']

# %%
roleArn = iam.get_role(RoleName=DWH_IAM_ROLE_NAME)['Role']['Arn']

# %%
try:
  response = redshift.create_cluster(
  ClusterType=DWH_CLUSTER_TYPE,
  NodeType=DWH_NODE_TYPE,

  #Identifiers and Credentials
  DBName=DWH_DB,
  ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,
  MasterUsername=DWH_DB_USER,
  MasterUserPassword=DWH_DB_PASSWORD,
    
  #Roles (for s3 access)
  IamRoles=[roleArn]
  )
except Exception as e:
  print(e)
# Out:
# An error occurred (ClusterAlreadyExists) when calling the CreateCluster operation: Cluster already exists

# %%
redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
# Out:
# {'AllowVersionUpgrade': True,
#  'AquaConfiguration': {'AquaConfigurationStatus': 'auto',
#   'AquaStatus': 'disabled'},
#  'AutomatedSnapshotRetentionPeriod': 1,
#  'AvailabilityZone': 'ap-south-1b',
#  'AvailabilityZoneRelocationStatus': 'disabled',
#  'ClusterAvailabilityStatus': 'Available',
#  'ClusterCreateTime': datetime.datetime(2022, 4, 11, 12, 37, 32, 142000, tzinfo=tzlocal()),
#  'ClusterIdentifier': 'my-first-redshift',
#  'ClusterNamespaceArn': 'arn:aws:redshift:ap-south-1:325093416967:namespace:8037c961-0b69-4c1f-8f0b-b67326b42bc8',
#  'ClusterNodes': [{'NodeRole': 'SHARED',
#    'PrivateIPAddress': '172.31.5.142',
#    'PublicIPAddress': '43.204.53.87'}],
#  'ClusterParameterGroups': [{'ParameterApplyStatus': 'in-sync',
#    'ParameterGroupName': 'default.redshift-1.0'}],
#  'ClusterPublicKey': 'ssh-rsa  Amazon-Redshift\n',
#  'ClusterRevisionNumber': '37176',
#  'ClusterSecurityGroups': [],
#  'ClusterStatus': 'available',
#  'ClusterSubnetGroupName': 'default',
#  'ClusterVersion': '1.0',
#  'DBName': 'myfirstdb',
#  'DeferredMaintenanceWindows': [],
#  'Encrypted': False,
#  'Endpoint': {'Address': 'my-first-redshift.c92z4nm0ycht.ap-south-1.redshift.amazonaws.com',
#   'Port': 5439},
#  'EnhancedVpcRouting': False,
#  'IamRoles': [{'ApplyStatus': 'in-sync',
#    'IamRoleArn': 'arn:aws:iam::325093416967:role/redshift-s3-access'}],
#  'MaintenanceTrackName': 'current',
#  'ManualSnapshotRetentionPeriod': -1,
#  'MasterUsername': 'awsuser',
#  'NextMaintenanceWindowStartTime': datetime.datetime(2022, 4, 14, 6, 0, tzinfo=tzlocal()),
#  'NodeType': 'dc2.large',
#  'NumberOfNodes': 1,
#  'PendingModifiedValues': {},
#  'PreferredMaintenanceWindow': 'thu:06:00-thu:06:30',
#  'PubliclyAccessible': True,
#  'Tags': [],
#  'TotalStorageCapacityInMegaBytes': 400000,
#  'VpcId': 'vpc-08df5a4dae60480e0',
#  'VpcSecurityGroups': [{'Status': 'active',
#    'VpcSecurityGroupId': 'sg-0468c1ee5095470f1'}]}

# %%
def prettyRedshiftProps(props):
  pd.set_option('display.max_colwidth', -1)
  keysToShow = ["ClusterIdentifier", "NodeType","ClusterStatus", "MasterUsername", "Endpoint", "VpcId"]
  x = [(k, v) for k,v in props.items() if k in keysToShow]
  return pd.DataFrame(data=x, columns=["Key", "Value"])

myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#                  Key  \
# 0  ClusterIdentifier
# 1  NodeType
# 2  ClusterStatus
# 3  MasterUsername
# 4  Endpoint
# 5  VpcId
#
#                                                                                            Value
# 0  my-first-redshift
# 1  dc2.large
# 2  available
# 3  awsuser
# 4  {'Address': 'my-first-redshift.c92z4nm0ycht.ap-south-1.redshift.amazonaws.com', 'Port': 5439}
# 5  vpc-08df5a4dae60480e0

# %%
DWH_ENDPOINT = myClusterProps['Endpoint']['Address']
DWH_ROLE_ARN = myClusterProps['IamRoles'][0]['IamRoleArn']
DB_NAME = myClusterProps['DBName']
DWH_DB_USER = myClusterProps['MasterUsername']

# %%
try:
  vpc = ec2.Vpc(id=myClusterProps['VpcId'])
  defaultSg = list(vpc.security_groups.all())[0]
  print(defaultSg)

  defaultSg.authorize_ingress(
      GroupName = defaultSg.group_name,
      CidrIp = '0.0.0.0/0',
      IpProtocol='TCP',
      FromPort=int(DWH_PORT),
      ToPort=int(DWH_PORT)
  )

except Exception as e:
  print(e)
# Out:
# ec2.SecurityGroup(id='sg-0468c1ee5095470f1')
# An error occurred (InvalidPermission.Duplicate) when calling the AuthorizeSecurityGroupIngress operation: the specified rule "peer: 0.0.0.0/0, TCP, from port: 5439, to port: 5439, ALLOW" already exists

# %%
try:
  conn = psycopg2.connect(host=DWH_ENDPOINT, dbname=DB_NAME, user=DWH_DB_USER, password="Arun0006", port=5439)
except psycopg2.Error as ec2:
  print ("Error : could not make connection to Postgres database")
  print(e)

conn.set_session(autocommit=True)

# %%
try:
  cur= conn.cursor()
except psycopg2.Error as e:
  print("Error:Could not get curser to the Database")
  print(e)

# %%
try:
  cur.execute("""create table users(
  userid integer not null distkey sortkey,
  username char(8),
  firstname varchar(30),
  lastname varchar(30),
  city varchar(30),
  state char(2),
  email varchar(100),
  phone char(14),
  likesports boolean,
  liketheatre boolean,
  likeconcerts boolean,
  likejazz boolean,
  likeclassical boolean,
  likeopera boolean,
  likerock boolean,
  likevegas boolean,
  likebroadway boolean,
  likemusicals boolean);""")
except psycopg2.Error as e:
  print("Error: Issue creating table")
  print(e)
# Out:
# Error: Issue creating table
# Relation "users" already exists

# %%
try:
  cur.execute("""create table venue(
  venueid smallint not null distkey sortkey,
  venuename varchar(100),
  venuecity varchar(30),
  venuestate char(2),
  venueseats integer);""")
except psycopg2.Error as e:
  print("Error:Issue creating table")
  print(e)
# Out:
# Error:Issue creating table
# Relation "venue" already exists

# %%
try:
  cur.execute("""create table category(
  catid smallint not null distkey sortkey,
  catgroup varchar(10),
  catname varchar(10),
  catdesc varchar(50));

create table date(
  dateid smallint not null distkey sortkey,
  caldate date not null,
  day character(3) not null,
  week smallint not null,
  month character(5) not null,
  qtr character(5) not null,
  year smallint not null,
  holiday boolean default('N'));

create table event(
  eventid integer not null distkey ,
  venueid smallint not null,
  catid smallint not null,
  dateid smallint not null sortkey,
  eventname varchar(200),
  starttime timestamp);  

create table listing(
  listid integer not null distkey ,
  sellerid integer not null,
  eventid integer not null,
  dateid smallint not null sortkey,
  numtickets smallint not null,
  priceperticket decimal(8,2), 
  totalprice decimal(8, 2),
  listtime timestamp);

       """)
except psycopg2.Error as e:
  print("Error: Issue creating table")
  print(e)
# Out:
# Error: Issue creating table
# Relation "category" already exists

# %%
try:
  cur.execute("""
  copy users from 's3://arun-test-bucket-global/allusers_pipe.txt'
  credentials 'aws_iam_role=arn:aws:iam::325093416967:role/redshift-s3-access'
  delimiter '|'
  region 'ap-south-1'
  
  
  """)
except psycopg2.Error as e:
  print("Error: Issue creating table")
  print(e)

# %%
try:
  cur.execute("""
     select * from users;
  
  
  """)
except psycopg2.Error as e:
  print("Error: Issue creating table")
  print(e)

# %%
row = cur.fetchone()
while row:
  print(row)
  row = cur.fetchone()
# Out:
# Streaming output truncated to the last 5000 lines.
# (19978, 'OJV08GKV', 'Uriah', 'Craig', 'Shelton', 'AK', 'dis.parturient@SuspendisseduiFusce.org', '(944) 530-9484', False, None, None, None, False, True, None, None, None, True)
# (19982, 'JVU68XAN', 'Erin', 'Reeves', 'Little Rock', 'GA', 'at.auctor@Aenean.com', '(744) 522-9780', None, None, None, None, True, False, False, False, None, None)
# (19983, 'URA29HFT', 'Bevis', 'Daniels', 'Clarksville', 'SK', 'at.iaculis@nisisem.org', '(264) 324-0470', True, None, None, False, None, False, False, False, False, True)
# (19985, 'QOC55ZDR', 'Naomi', 'Sweet', 'Pittston', 'YT', 'et@egestasblanditNam.ca', '(987) 843-1960', None, False, None, None, True, None, False, None, False, True)
# (19987, 'PBB30CCW', 'Alden', 'Velazquez', 'Grand Forks', 'NU', 'auctor.odio.a@Nullam.edu', '(189) 856-3739', None, True, True, True, None, True, None, None, None, False)
# (19988, 'KKG29XOQ', 'Deanna', 'Knox', 'Calabasas', 'AK', 'ac.mattis@eget.ca', '(797) 634-7451', None, None, False, False, False, False, None, True, False, True)
# (19996, 'GWU71PLD', 'Ishmael', 'Bartlett', 'Lancaster', 'MI', 'at.pretium@adipiscingenim.edu', '(940) 258-0827', None, True, True, None, None, None, None, None, None, False)
# (19997, 'EZD64DQN', 'Lani', 'Waller', 'Cheyenne', 'UT', 'erat.volutpat.Nulla@tellus.ca', '(249) 980-7830', None, True, False, False, False, None, None, None, None, False)
# (19999, 'VGL47DLI', 'Yoshio', 'Atkinson', 'Seattle', 'KY', 'iaculis.aliquet.diam@hendreritDonec.ca', '(677) 252-8638', True, True, None, None, True, True, True, None, None, None)
# (20002, 'WDZ66XMN', 'Bree', 'Nichols', 'Malibu', 'NT', 'eu@gravidasagittis.edu', '(322) 878-5900', None, None, True, None, None, False, False, None, True, False)
# (20004, 'LEH04FBG', 'acqueline', 'Stewart', 'Rialto', 'SK', 'et@inaliquet.edu', '(251) 775-4602', None, None, True, None, False, True, None, False, None, False)
# (20007, 'HHC36HQR', 'Felicia', 'Todd', 'Arvada', 'NT', 'risus.Quisque@sedest.edu', '(952) 818-2775', None, None, None, True, True, True, None, False, None, None)
# (20008, 'HAY11UKZ', 'Kane', 'Tate', 'Tucson', 'PE', 'lacus@lacusvestibulumlorem.org', '(553) 999-9932', None, None, True, False, False, False, True, False, None, False)
# (20010, 'SNJ31IOW', 'Orli', 'Frost', 'Edmond', 'AZ', 'vulputate@parturientmontesnascetur.com', '(250) 924-8713', False, None, None, False, None, None, False, None, None, False)
# (20011, 'KFP34BGE', 'Dakota', 'Morse', 'Richmond', 'PA', 'eget@tincidunt.edu', '(275) 669-8711', None, False, False, None, None, False, True, False, True, None)
# (20016, 'DVI49THA', 'Bradley', 'Walsh', 'Inglewood', 'GA', 'Sed@felisNulla.ca', '(195) 730-3259', None, False, True, True, False, False, None, None, None, False)
# (20018, 'LYT83JFI', 'Camille', 'Davenport', 'York', 'AB', 'a.arcu@purusmauris.org', '(220) 160-2315', None, None, False, None, True, None, False, None, None, True)
# (20019, 'VFX88XBF', 'Axel', 'Mooney', 'Gary', 'NL', 'felis.purus@VivamusrhoncusDonec.org', '(528) 370-3910', None, None, True, True, None, None, None, True, True, None)
# (20021, 'TXG68XMM', 'Brenna', 'Winters', 'Fulton', 'OH', 'lobortis.quis@tellus.edu', '(102) 131-1645', False, False, None, None, None, None, False, None, None, None)
# (20024, 'UPX91MGN', 'Luke', 'Collins', 'Lufkin', 'NL', 'sociosqu@in.ca', '(495) 888-5993', None, False, None, False, False, None, True, None, None, None)
# (20025, 'YLP73KHH', 'Hedy', 'Mcclure', 'Montgomery', 'PE', 'semper.pretium.neque@tellusPhasellus.edu', '(194) 154-5361', False, None, True, False, False, False, False, True, None, None)
# (20027, 'FDX33ZJH', 'Bevis', 'Salinas', 'Logan', 'NB', 'Quisque.nonummy.ipsum@maurisid.org', '(992) 472-1116', None, False, None, None, False, None, False, None, None, None)
# (20029, 'RPM45HGY', 'Drew', 'Mcguire', 'Lancaster', 'AB', 'tellus.lorem.eu@vulputatevelit.com', '(224) 440-3543', None, None, None, True, False, None, None, None, None, True)
# (20031, 'BTP36SEP', 'Denton', 'Barry', 'Joliet', 'NS', 'tempor.lorem.eget@molestietellusAenean.org', '(673) 284-9410', False, None, None, True, True, True, None, None, False, False)
# (20034, 'SLC94XYW', 'Kathleen', 'Chandler', 'Helena', 'MT', 'malesuada.vel.convallis@dolor.com', '(616) 217-2290', True, None, True, True, None, True, None, None, None, True)
# (20036, 'SEW84SHT', 'Nola', 'Hoffman', 'Aurora', 'NL', 'tincidunt@nunc.ca', '(540) 855-5919', None, None, True, True, None, None, None, False, False, True)
# (20037, 'RJS59GCX', 'George', 'Boyer', 'Ardmore', 'QC', 'velit@enim.edu', '(574) 184-9912', True, None, None, True, None, False, False, None, False, None)
# (20039, 'EXP47RDO', 'Kai', 'George', 'Haverhill', 'NB', 'pretium.neque@quis.ca', '(232) 606-7068', True, False, None, True, None, False, False, False, None, True)
# (20040, 'BYG60YJB', 'Lesley', 'Carter', 'Woburn', 'DE', 'egestas.nunc@atauctor.edu', '(569) 933-4442', None, True, True, False, None, None, None, True, None, None)
# (20041, 'QWF62PBS', 'August', 'Greer', 'Poughkeepsie', 'OH', 'Donec@tellusimperdiet.edu', '(724) 771-5627', None, True, None, None, False, None, False, False, True, None)
# (20042, 'JNI12LSW', 'Nichole', 'Hubbard', 'Peekskill', 'NB', 'eros.Proin.ultrices@tristique.ca', '(873) 275-1037', None, True, None, True, True, None, False, True, None, None)
# (20046, 'YFE95JCJ', 'Carly', 'Meyers', 'Honolulu', 'TN', 'Nunc@pharetranibh.edu', '(226) 557-6837', True, False, False, None, True, None, None, True, None, None)
# (20047, 'RFD17WWP', 'Cruz', 'Neal', 'Clairton', 'MA', 'enim@mus.ca', '(924) 177-8423', None, True, None, False, False, False, None, None, None, False)
# (20048, 'IGT39NGK', 'Quamar', 'Monroe', 'Sitka', 'ND', 'erat.in@Aeneaneuismodmauris.ca', '(827) 139-1625', True, False, None, False, None, None, None, True, False, True)
# (20052, 'ZKE75VMO', 'Isaiah', 'Griffith', 'Schenectady', 'MB', 'mi.fringilla@risusDonecegestas.com', '(165) 274-6611', None, True, False, False, False, True, None, None, None, True)
# (20055, 'LTR60XJA', 'Tatyana', 'Frazier', 'Wheeling', 'MB', 'est@ipsumprimisin.org', '(867) 395-4048', None, None, False, None, None, False, None, False, None, None)
# (20060, 'RTK10KHH', 'Barclay', 'Pace', 'Bismarck', 'ON', 'pellentesque.massa@consectetuer.edu', '(954) 721-6661', True, None, None, None, True, True, None, None, False, None)
# (20061, 'IYH02LQW', 'August', 'Sims', 'Hagerstown', 'OK', 'ultrices.posuere.cubilia@maurissitamet.edu', '(670) 398-4748', None, None, None, True, None, True, False, None, None, False)
# (20063, 'IGL81HQN', 'Elliott', 'Mckay', 'Maywood', 'KS', 'turpis.non.enim@volutpatNulladignissim.org', '(633) 808-3017', None, None, True, True, None, None, True, True, False, False)
# (20065, 'IEL42NFX', 'Darius', 'Dominguez', 'Lake Charles', 'MB', 'dolor.Quisque@Duisdignissimtempor.ca', '(507) 824-0798', None, False, True, True, False, None, None, True, None, None)
# (20068, 'HYW60JSN', 'Ruby', 'Short', 'Idaho Falls', 'NS', 'lectus.Nullam.suscipit@dictumplacerataugue.ca', '(335) 830-6196', True, True, True, None, None, None, None, False, None, None)
# (20069, 'ZRN80OMF', 'Kelly', 'Cantu', 'West Hollywood', 'AK', 'a@Nullamvelit.edu', '(721) 466-1878', None, False, True, False, None, None, False, True, False, None)
# (20076, 'FSX78PSJ', 'Rachel', 'Rogers', 'Zanesville', 'NL', 'nulla.Cras@Infaucibus.com', '(312) 435-2639', None, False, True, True, True, None, True, None, None, True)
# (20077, 'EWD51RUV', 'Amity', 'Ratliff', 'Rye', 'NT', 'a.ultricies.adipiscing@dictumauguemalesuada.org', '(820) 710-0648', None, None, False, None, None, None, False, None, False, False)
# (20079, 'IMH42CYE', 'Reed', 'Santana', 'Yonkers', 'VT', 'a.ultricies@enimmitempor.ca', '(714) 879-3175', None, None, None, False, None, None, None, None, False, True)
# (20080, 'WBD78CAY', 'Scarlett', 'Mcmillan', 'Lancaster', 'BC', 'ultricies.adipiscing@ametornarelectus.edu', '(272) 512-7118', None, None, None, True, True, None, True, True, True, True)
# (20081, 'UPY37ECY', 'Emily', 'Abbott', 'Austin', 'AB', 'ad.litora.torquent@fermentum.ca', '(278) 665-5202', None, True, None, False, None, None, None, False, None, None)
# (20083, 'QIA89YSV', 'Faith', 'Knox', 'Torrington', 'MN', 'nec.malesuada@elementumategestas.edu', '(418) 280-7606', None, None, None, None, True, None, True, False, False, None)
# (20086, 'ADC36AHU', 'Savannah', 'Levine', 'Tok', 'MA', 'tincidunt.pede@Crasvulputatevelit.edu', '(977) 816-8066', None, True, False, None, True, True, False, False, None, None)
# (20088, 'NOJ56CDZ', 'Ayanna', 'Fuller', 'La Crosse', 'AL', 'vestibulum.massa.rutrum@lectussit.com', '(943) 129-2305', False, None, True, None, False, None, False, None, None, False)
# (20089, 'MYR51QTM', 'Mohammad', 'Gonzalez', 'Davenport', 'MI', 'aliquam.eu.accumsan@feugiatmetus.ca', '(458) 739-9904', True, None, None, False, None, False, False, True, None, True)
# (20090, 'QKT37SGU', 'Patrick', 'Osborne', 'Fargo', 'NM', 'nonummy@dapibus.com', '(439) 729-5907', False, None, False, None, False, False, None, False, None, None)
# (20093, 'NNG39KPX', 'Xanthus', 'Gallagher', 'Williamsburg', 'MA', 'eros.Proin.ultrices@nunc.com', '(620) 762-9450', True, None, False, None, None, False, False, None, None, None)
# (20095, 'YKV95KBA', 'Berk', 'David', 'San Marino', 'NL', 'Aliquam@Utnec.ca', '(710) 311-3513', None, True, None, False, None, False, None, None, True, True)
# (20096, 'QVZ89CHL', 'Doris', 'Mullen', 'Starkville', 'WI', 'Vestibulum.ante@amet.org', '(440) 586-8566', None, None, None, False, None, None, False, False, None, True)
# (20097, 'IKY82QRV', 'Eve', 'Greer', 'Anaheim', 'YT', 'at.risus@amet.com', '(525) 716-6606', True, True, False, None, None, False, True, None, None, None)
# (20098, 'ORL38CZM', 'Brennan', 'Mills', 'Areceibo', 'NJ', 'egestas.urna.justo@enim.ca', '(207) 372-3075', None, None, None, None, False, None, None, False, None, None)
# (20099, 'XLQ12XPG', 'Lucius', 'Bowen', 'Port Jervis', 'DC', 'malesuada@Seddiamlorem.ca', '(469) 985-4951', None, False, None, True, None, False, False, True, True, None)
# (20100, 'GZP28DSV', 'Nerea', 'Trujillo', 'Cruz Bay', 'BC', 'Nullam@a.edu', '(462) 443-2400', False, False, True, None, None, None, None, True, True, True)
# (20101, 'FJZ58IWG', 'Hillary', 'West', 'Baldwin Park', 'IN', 'elit.fermentum@Vestibulumaccumsan.edu', '(901) 633-3881', None, True, True, True, False, True, None, True, False, True)
# (20102, 'FXC82MEE', 'Glenna', 'Francis', 'Pittsburgh', 'NC', 'Praesent.interdum@euismod.com', '(281) 232-0203', None, False, None, True, None, False, False, True, None, None)
# (20103, 'EXQ42WLM', 'Wesley', 'Reyes', 'Malibu', 'YT', 'tempus@acfacilisisfacilisis.edu', '(150) 245-8958', False, True, None, True, True, False, None, False, False, None)
# (20104, 'KQV60INA', 'Taylor', 'Hamilton', 'Akron', 'MA', 'vel.convallis@Sed.org', '(673) 713-3696', False, None, False, False, None, False, False, None, False, True)
# (20106, 'MVY27JLC', 'Malachi', 'Barry', 'Altoona', 'NU', 'metus.In@feugiat.org', '(939) 992-2094', True, False, None, True, None, False, None, False, True, None)
# (20107, 'SPE65JYP', 'Gay', 'Hodge', 'Forest Lake', 'MD', 'placerat.orci@Aliquam.com', '(561) 965-5112', None, None, True, True, None, False, None, None, None, False)
# (20108, 'WHP79FID', 'Fitzgerald', 'Mejia', 'Merced', 'NH', 'ipsum@nunc.ca', '(307) 611-9512', None, None, False, None, True, False, None, False, True, None)
# (20110, 'HCZ39MCI', 'Lester', 'Ochoa', 'Atlanta', 'BC', 'sed.turpis.nec@aliquetlobortisnisi.com', '(802) 150-1375', True, None, None, None, None, False, False, True, False, None)
# (20114, 'HFU86GYW', 'Rinah', 'Oliver', 'Starkville', 'NS', 'ac@id.com', '(248) 570-9633', None, None, None, False, True, None, None, False, None, None)
# (20117, 'XZF57PLN', 'Cailin', 'Jordan', 'Rancho Cucamonga', 'NL', 'dolor.sit.amet@aenim.ca', '(233) 540-1566', None, None, None, None, None, None, True, None, True, True)
# (20118, 'BGB56DTG', 'Rosalyn', 'Griffin', 'Glendale', 'NB', 'nec.imperdiet.nec@Phasellus.org', '(665) 732-1190', None, None, True, False, None, False, True, True, False, None)
# (20119, 'UQP40VQD', 'Robin', 'Odom', 'Blacksburg', 'NS', 'eleifend@et.org', '(464) 850-7469', None, None, None, None, None, False, None, True, True, False)
# (20122, 'VCM08BBB', 'Sheila', 'Pugh', 'Newport News', 'MB', 'urna@nequeNullamnisl.ca', '(910) 240-6292', None, True, None, None, None, False, None, False, None, None)
# (20124, 'IGG50IFZ', 'May', 'Gaines', 'Hawthorne', 'MB', 'amet.luctus.vulputate@justonec.com', '(111) 317-7919', None, True, True, None, True, None, False, True, None, False)
# (20125, 'FWN40HEA', 'Hashim', 'Cannon', 'Meadville', 'QC', 'lobortis.Class@ultrices.com', '(916) 207-7788', None, None, False, True, None, True, None, None, False, None)
# (20126, 'KIK53DGC', 'Wendy', 'Cantu', 'Monterey Park', 'HI', 'velit.egestas.lacinia@penatibuset.com', '(892) 805-1705', True, None, None, None, False, False, None, None, False, False)
# (20127, 'GTN08ADO', 'Aretha', 'Pearson', 'Hoover', 'ND', 'Suspendisse@nisl.ca', '(687) 828-9463', None, False, True, None, None, True, None, None, None, None)
# (20131, 'PIS83WFT', 'Caesar', 'Salas', 'Carolina', 'QC', 'lectus.pede@maurisa.org', '(280) 486-9070', None, False, None, None, False, None, None, None, True, None)
# (20132, 'ZEH30YHC', 'Noelle', 'Ford', 'Lansing', 'NB', 'Nulla.aliquet@nec.edu', '(105) 914-1619', True, None, None, True, None, True, True, False, None, False)
# (20133, 'FBU11GIW', 'Hope', 'Dyer', 'Sioux City', 'QC', 'dictum.eleifend@dictum.ca', '(558) 315-2464', None, None, True, False, False, None, None, None, None, True)
# (20135, 'WJU46NKT', 'Eagan', 'Vaughn', 'Rolla', 'AB', 'nisi.Cum@loremvehicula.edu', '(847) 831-7003', None, False, False, False, None, None, None, None, None, None)
# (20139, 'PCZ71SCT', 'Cora', 'Carney', 'Irving', 'NT', 'elit.Curabitur@scelerisqueduiSuspendisse.org', '(840) 372-1918', None, None, None, False, None, None, None, None, None, True)
# (20140, 'OBV88CYT', 'Clayton', 'Riddle', 'Bentonville', 'NT', 'Pellentesque.tincidunt@tempor.org', '(468) 109-0008', False, True, None, False, None, False, None, False, None, True)
# (20150, 'FFZ79RVH', 'Belle', 'French', 'West Palm Beach', 'MB', 'et.rutrum@Proinvelit.com', '(851) 567-8922', None, False, None, None, False, None, None, True, None, None)
# (20151, 'DUR64KLJ', 'Nadine', 'Morrison', 'Radford', 'BC', 'Sed.molestie@enimSednulla.com', '(675) 401-2824', None, False, None, True, True, None, False, False, True, True)
# (20152, 'EJN53RTG', 'Vera', 'Delaney', 'Frankfort', 'PE', 'Nullam@tinciduntvehicula.org', '(250) 624-3308', False, None, True, None, False, False, False, None, True, None)
# (20159, 'IVP07FGL', 'Dorian', 'Dillon', 'Woodward', 'PE', 'luctus.sit@etrisus.edu', '(284) 202-1550', None, None, None, None, None, False, None, None, True, False)
# (20162, 'PRA07IZG', 'Adele', 'Mason', 'Blythe', 'KY', 'consectetuer.adipiscing@tellusfaucibus.org', '(350) 755-8429', None, None, False, None, None, None, None, None, True, False)
# (20164, 'ERZ37CRU', 'Pearl', 'Ramos', 'Hermosa Beach', 'NS', 'Duis.cursus@facilisi.edu', '(690) 752-9224', None, True, True, True, False, None, False, False, False, True)
# (20165, 'XPY61FQK', 'Hope', 'Bowman', 'Owensboro', 'OR', 'ante.ipsum@molestie.com', '(877) 760-6188', True, None, None, False, False, None, None, None, True, None)
# (20166, 'IXU05VQS', 'Martina', 'Knox', 'Malden', 'IA', 'ligula@Nullafacilisis.ca', '(410) 149-2358', None, None, None, None, True, None, None, None, None, None)
# (20170, 'FPE39MOK', 'Madonna', 'Tate', 'Moscow', 'QC', 'et.nunc.Quisque@vitae.ca', '(781) 138-6339', None, None, None, None, None, True, None, None, True, True)
# (20171, 'FLS27NXD', 'Urielle', 'Sargent', 'Meriden', 'VA', 'Integer.urna.Vivamus@acmattis.com', '(952) 901-2587', None, False, None, False, None, False, True, True, None, True)
# (20175, 'EDD02XDT', 'Kimberly', 'Kemp', 'Hilo', 'ON', 'nec.eleifend@fermentumconvallis.org', '(371) 756-5708', False, False, None, None, True, False, None, True, None, True)
# (20177, 'EWU64XVZ', 'Echo', 'Bowen', 'Edina', 'NS', 'bibendum.Donec@eleifendnuncrisus.org', '(584) 616-0539', None, None, True, None, True, True, None, True, True, None)
# (20178, 'EDC72TTV', 'Ava', 'Owen', 'Charleston', 'QC', 'et@nuncnullavulputate.edu', '(548) 362-1417', True, True, False, False, True, None, None, None, False, True)
# (20179, 'UAO06VDC', 'Xandra', 'Walton', 'Sandy', 'VT', 'non.enim@vitaenibhDonec.edu', '(781) 820-1055', False, True, None, False, None, None, None, True, True, True)
# (20184, 'MQY52KRG', 'Hanna', 'Knapp', 'Camden', 'NB', 'adipiscing.non@bibendumfermentum.com', '(142) 792-8146', False, True, True, None, None, False, False, True, False, None)
# (20185, 'IPA04HWQ', 'Ralph', 'Joyce', 'Murfreesboro', 'QC', 'lorem.lorem.luctus@mauris.org', '(294) 595-1403', True, None, True, None, None, None, True, None, False, False)
# (20188, 'VTJ47ANI', 'Bruno', 'Nolan', 'Sierra Vista', 'TX', 'et@loremfringilla.ca', '(316) 410-9937', None, False, True, None, False, None, None, None, True, None)
# (20191, 'GBJ12QRE', 'Damian', 'Fox', 'Ann Arbor', 'NB', 'nec.orci.Donec@augueeu.ca', '(741) 821-3357', None, None, None, None, True, None, False, True, False, None)
# (20194, 'ICA70ARY', 'Meghan', 'House', 'Chattanooga', 'WI', 'ultrices@orcisemeget.com', '(606) 455-6803', None, True, None, False, False, True, None, False, None, True)
# (20196, 'LJO64IKV', 'Jaden', 'Kinney', 'Turlock', 'NM', 'a.dui.Cras@diamDuismi.org', '(385) 316-4525', True, None, True, None, True, None, None, None, None, None)
# (20199, 'TEW38UUP', 'Basil', 'Bailey', 'Syracuse', 'ME', 'malesuada.vel@nec.ca', '(928) 865-7517', None, False, False, True, True, True, True, False, True, False)
# (20201, 'ZMI23UEP', 'Tamekah', 'Sawyer', 'Manassas', 'NL', 'sapien@egetmagnaSuspendisse.edu', '(313) 360-4300', False, None, None, False, None, None, None, None, None, True)
# (20203, 'FTW88GVD', 'Brenna', 'Rasmussen', 'Jeffersonville', 'WV', 'Donec@Morbinequetellus.org', '(283) 652-6431', None, None, None, None, None, True, None, None, None, None)
# (20204, 'LFI08NUH', 'Todd', 'Tanner', 'Parma', 'GA', 'neque@vestibulumloremsit.com', '(811) 438-7739', None, None, False, None, None, None, None, True, True, None)
# (20205, 'QJK06HUL', 'Lilah', 'Rosales', 'Milford', 'ID', 'pellentesque.tellus@metus.edu', '(573) 797-6454', False, None, None, True, None, True, None, True, True, None)
# (20213, 'QZI58SDD', 'Charity', 'Frye', 'Clarksville', 'AB', 'Mauris@estmaurisrhoncus.org', '(272) 709-3105', False, False, False, None, False, None, None, None, False, False)
# (20214, 'GMJ05JIR', 'Hiram', 'Stafford', 'Flagstaff', 'AK', 'dui.in.sodales@consectetuer.org', '(809) 533-6997', False, None, None, False, None, None, False, False, None, None)
# (20215, 'QFR15AWL', 'Alice', 'Mcmahon', 'Bentonville', 'MB', 'Donec.consectetuer.mauris@ligulaNullamenim.ca', '(281) 844-3841', None, None, True, True, None, None, None, True, False, None)
# (20219, 'PCN45XND', 'Skyler', 'Fitzpatrick', 'Wheeling', 'NL', 'amet.faucibus.ut@Sednunc.edu', '(646) 248-6820', None, None, None, None, True, True, None, False, True, None)
# (20220, 'GSU42RBC', 'Stephanie', 'Bowers', 'Eufaula', 'OK', 'fringilla.mi.lacinia@sedconsequat.com', '(362) 397-2178', None, None, False, None, None, True, False, None, None, None)
# (20221, 'AWU28PMZ', 'Hector', 'French', 'Kemmerer', 'ME', 'et@malesuadaaugueut.com', '(561) 244-5862', None, False, True, False, False, None, None, False, True, False)
# (20224, 'RRH15LVR', 'Daria', 'Albert', 'Commerce', 'PE', 'scelerisque.sed@anteVivamusnon.org', '(884) 711-0246', False, None, True, False, False, None, False, None, None, None)
# (20228, 'RCB64YLI', 'Francesca', 'Boone', 'Marshfield', 'MB', 'metus.facilisis.lorem@est.edu', '(949) 185-6031', True, True, None, True, False, None, None, False, True, False)
# (20230, 'QGF37EQM', 'Amir', 'Noel', 'Suffolk', 'AB', 'blandit@velpedeblandit.org', '(639) 186-2223', None, True, None, True, False, True, None, None, False, False)
# (20231, 'XGE91VFK', 'Anika', 'Leblanc', 'Troy', 'MO', 'at.pede@sagittis.ca', '(254) 964-2715', None, True, None, None, False, None, None, None, None, None)
# (20232, 'JQS32DQB', 'Deacon', 'Cohen', 'Riverside', 'NM', 'diam@tempusnonlacinia.org', '(408) 825-8800', False, False, True, None, False, True, None, None, None, False)
# (20233, 'PAZ32OGC', 'Lionel', 'Goff', 'Boulder', 'SD', 'et.magnis.dis@Donecegestas.edu', '(648) 351-7859', True, True, True, None, None, False, False, True, None, False)
# (20237, 'SEV91BRD', 'Madonna', 'Lloyd', 'Pierre', 'QC', 'eleifend.non@ac.edu', '(122) 616-1301', True, False, False, None, None, None, False, None, False, False)
# (20240, 'JMX81ZFT', 'Dacey', 'Greer', 'Tustin', 'AB', 'commodo.hendrerit.Donec@diamvel.ca', '(855) 806-9077', False, None, False, False, None, False, True, None, True, None)
# (20241, 'UUW58MMZ', 'Darrel', 'Cochran', 'Pomona', 'IL', 'dui.nec.urna@dictum.com', '(439) 439-7147', None, None, None, None, False, True, None, False, None, True)
# (20244, 'PJY30WHG', 'Gretchen', 'Chen', 'Kokomo', 'UT', 'sed@nonmassanon.org', '(829) 483-6717', False, True, True, False, None, None, False, None, None, True)
# (20247, 'SPI09EUM', 'Hermione', 'Bowen', 'Waterloo', 'QC', 'mollis.dui@ametornarelectus.org', '(753) 794-3869', None, None, True, None, None, False, None, None, False, None)
# (20248, 'ATU77HCP', 'Yuri', 'Benton', 'Anderson', 'PE', 'at.nisi.Cum@dapibusquamquis.edu', '(376) 616-1043', None, True, None, False, None, None, False, None, False, True)
# (20250, 'DRT29OUT', 'Susan', 'Mills', 'Azusa', 'CT', 'diam.nunc.ullamcorper@nequeet.edu', '(913) 165-9803', False, None, False, None, None, None, None, False, None, False)
# (20252, 'MCF31VYI', 'Mira', 'Walters', 'Goose Creek', 'YT', 'elit.elit.fermentum@aliquameros.ca', '(873) 671-2162', None, None, None, None, False, False, None, True, False, None)
# (20253, 'UWC46ESU', 'Rhoda', 'Wall', 'Agat', 'MB', 'lacinia.orci.consectetuer@massaQuisqueporttitor.org', '(646) 757-4464', None, None, False, False, False, None, True, None, False, False)
# (20254, 'RGZ47SWG', 'Herrod', 'Faulkner', 'Starkville', 'QC', 'ut@commodoat.com', '(537) 407-6537', None, True, False, None, True, False, False, True, False, False)
# (20255, 'TBW10PUP', 'Wang', 'King', 'Vacaville', 'VT', 'ac@lobortisultricesVivamus.com', '(543) 908-7840', True, False, True, None, None, None, False, True, True, False)
# (20256, 'ZEQ92NQC', 'Ahmed', 'Moss', 'Oro Valley', 'ON', 'placerat@egetlacusMauris.edu', '(323) 594-1937', True, False, False, False, None, True, None, None, False, True)
# (20257, 'JZE89RZW', 'Abbot', 'Ortiz', 'Leominster', 'NU', 'tortor.Integer.aliquam@sed.edu', '(431) 264-2213', True, False, True, False, True, None, None, False, True, True)
# (20258, 'GCY47JSZ', 'Justin', 'Barton', 'Villa Park', 'OR', 'Duis.sit@aliquamenimnec.org', '(438) 674-1909', False, True, True, None, True, None, None, None, None, None)
# (20259, 'NOZ12LIF', 'Judith', 'Figueroa', 'West Lafayette', 'MO', 'vitae@lectusjusto.org', '(999) 500-8849', None, True, True, True, None, None, True, True, False, None)
# (20260, 'FFI63JOD', 'Reagan', 'Leblanc', 'Dana Point', 'AL', 'eu.dui.Cum@dictumeuplacerat.org', '(828) 805-6049', None, False, True, False, False, False, True, None, True, None)
# (20264, 'ZAB99ZKV', 'Uriel', 'Rose', 'Savannah', 'YT', 'Sed.pharetra@netus.org', '(548) 892-9458', True, True, True, False, None, None, False, None, None, None)
# (20265, 'DQV05BXZ', 'Lee', 'Ryan', 'Palo Alto', 'NB', 'nibh.enim.gravida@montesnasceturridiculus.org', '(527) 781-2038', None, False, False, None, None, False, None, None, False, True)
# (20266, 'YYK78OXW', 'Wynne', 'Rhodes', 'Bismarck', 'OR', 'in.faucibus@elitEtiam.org', '(863) 977-3768', None, None, None, None, None, None, True, None, True, False)
# (20269, 'TBN55MAV', 'Amethyst', 'Cannon', 'Chattanooga', 'CA', 'lorem@pedenonummy.edu', '(660) 551-5322', False, False, False, True, None, False, None, None, None, False)
# (20273, 'QXS82GCK', 'Tyler', 'Buckley', 'Topeka', 'SK', 'dolor@ametmetusAliquam.org', '(182) 313-2199', True, False, None, True, True, False, True, True, False, None)
# (20275, 'RDT19NKJ', 'Tucker', 'Beard', 'Erie', 'ON', 'Aliquam@lorem.ca', '(487) 289-3910', True, False, True, False, None, None, False, True, False, None)
# (20277, 'ZMJ66YGK', 'Anika', 'Warren', 'Ithaca', 'PE', 'cursus.non@Proinultrices.edu', '(342) 521-1568', True, None, True, None, None, False, None, True, False, False)
# (20278, 'QAJ12NHU', 'Carly', 'Clay', 'Frederick', 'BC', 'fringilla.euismod@velitAliquamnisl.com', '(909) 408-3787', None, None, True, True, None, None, None, True, True, None)
# (20280, 'AOA00HDD', 'Branden', 'Blackburn', 'Greenville', 'WA', 'Aliquam@sedleo.edu', '(103) 905-4610', False, None, None, None, False, None, None, False, None, False)
# (20285, 'GTM98FUC', 'Basil', 'Rutledge', 'McKeesport', 'ON', 'Morbi.metus.Vivamus@atnisi.ca', '(779) 786-6798', None, True, None, None, None, False, True, None, None, None)
# (20286, 'JVA06QTJ', 'Latifah', 'Maynard', 'Cary', 'NC', 'nibh.lacinia.orci@mi.org', '(501) 699-6503', None, None, False, True, None, None, None, None, None, None)
# (20288, 'UVV52JNT', 'Hunter', 'Ross', 'Fallon', 'VA', 'dolor.elit.pellentesque@risusDonec.edu', '(951) 414-3990', True, None, None, None, None, True, None, True, None, False)
# (20292, 'UCK31QZV', 'Sybill', 'Valenzuela', 'Lodi', 'RI', 'porttitor.tellus@vehiculaet.com', '(773) 814-1280', True, False, None, False, True, None, None, None, None, True)
# (20296, 'HNZ40STD', 'Dustin', 'James', 'Rancho Santa Margarita', 'QC', 'et.risus.Quisque@cursus.org', '(880) 128-4082', None, None, None, True, None, None, True, None, False, False)
# (20298, 'ZNT49DAE', 'Ciaran', 'Todd', 'Guthrie', 'PE', 'auctor.Mauris.vel@Fuscefermentum.edu', '(599) 392-8604', False, None, False, None, None, True, None, True, False, None)
# (20299, 'TXY99EVN', 'Danielle', 'Fitzgerald', 'Brownsville', 'NS', 'quis.pede@non.org', '(583) 180-0603', False, False, None, None, None, None, True, None, True, False)
# (20301, 'IWH40TWO', 'Odessa', 'Underwood', 'Wichita Falls', 'PE', 'purus@ametloremsemper.edu', '(871) 788-1514', None, None, None, False, True, True, None, True, None, True)
# (20304, 'TUG33XRP', 'Imani', 'Stark', 'Arcadia', 'PA', 'pretium@euismodindolor.ca', '(929) 580-7355', False, None, True, None, None, None, None, None, False, True)
# (20306, 'JPJ09NWY', 'Emerson', 'Patterson', 'Kokomo', 'NH', 'enim.Curabitur@consectetuermaurisid.com', '(298) 262-2133', True, None, False, None, None, None, None, True, True, None)
# (20308, 'GIH18LUC', 'Jasper', 'White', 'Mission Viejo', 'QC', 'commodo.tincidunt@Cras.edu', '(928) 840-0931', None, None, False, None, None, None, None, None, None, None)
# (20314, 'BGK80LUK', 'Meghan', 'Hahn', 'Rohnert Park', 'MO', 'est@ultrices.com', '(539) 368-8448', None, None, False, None, True, False, False, None, False, True)
# (20316, 'ZEM82ZUM', 'Alvin', 'Atkinson', 'Mankato', 'CO', 'condimentum@nonummyultriciesornare.com', '(184) 532-3159', None, None, True, None, None, True, True, None, False, None)
# (20317, 'GFW75BCR', 'Lewis', 'Allison', 'Thousand Oaks', 'NU', 'Praesent.eu.dui@liberoIntegerin.edu', '(187) 643-0932', None, True, None, False, False, None, False, True, True, None)
# (20318, 'WEV55EPO', 'Kelsie', 'Steele', 'Vail', 'NL', 'ornare.placerat.orci@dignissimpharetra.edu', '(404) 197-0869', None, None, None, True, None, False, False, True, False, None)
# (20320, 'DKD21CEJ', 'Valentine', 'Keith', 'West Palm Beach', 'NJ', 'est.ac.facilisis@at.org', '(403) 947-9912', None, True, True, True, None, None, None, None, False, None)
# (20323, 'ATC26XIL', 'Olivia', 'Norton', 'Coatesville', 'FL', 'Phasellus.nulla@amalesuadaid.ca', '(862) 459-7435', True, True, False, False, True, True, False, False, False, None)
# (20325, 'PPR86WRX', 'Zane', 'Park', 'Fredericksburg', 'QC', 'mattis.Cras@libero.com', '(531) 742-2544', False, None, True, True, False, None, None, True, True, None)
# (20328, 'PHZ51HIQ', 'Vance', 'Howe', 'West Allis', 'DE', 'pharetra@nostraper.org', '(651) 796-5986', None, False, True, None, None, False, True, None, True, False)
# (20335, 'NRO34YRZ', 'Wanda', 'Fuentes', 'Rock Springs', 'MA', 'Donec.nibh.Quisque@orciUt.edu', '(958) 167-1070', None, None, True, True, True, True, False, None, None, False)
# (20337, 'JVE68MWK', 'Daryl', 'Rocha', 'Webster Groves', 'NS', 'elit@id.ca', '(818) 374-8455', True, True, None, None, True, None, None, False, None, True)
# (20341, 'BPN66TKW', 'Priscilla', 'Mccray', 'Placentia', 'DE', 'In.at.pede@Proin.com', '(950) 111-8673', None, None, True, False, False, False, None, None, False, None)
# (20347, 'UEF51JZR', 'Carson', 'Blackwell', 'Schaumburg', 'AB', 'convallis.ligula@atpedeCras.ca', '(997) 685-5287', None, None, None, None, None, None, True, None, True, True)
# (20350, 'FWK98ULZ', 'Helen', 'Warren', 'Tuscaloosa', 'CA', 'purus@Sedetlibero.ca', '(899) 523-7411', False, False, None, True, False, True, None, None, None, None)
# (20351, 'GGA75INY', 'Kasimir', 'Odom', 'South El Monte', 'AK', 'in.consequat@Integer.edu', '(879) 497-8303', None, False, None, None, None, False, None, True, None, None)
# (20353, 'VUC37NTM', 'Wilma', 'Chen', 'Egg Harbor', 'NE', 'Fusce.fermentum@odio.edu', '(435) 430-9604', None, None, False, False, True, False, False, False, None, False)
# (20354, 'JYA73CTY', 'Charles', 'Cummings', 'New Haven', 'NU', 'elementum@et.org', '(181) 142-8658', None, None, True, None, None, False, False, None, False, False)
# (20355, 'NRG51LMT', 'Yoko', 'Ferrell', 'Ypsilanti', 'YT', 'Cras.eu.tellus@vestibulumneceuismod.edu', '(221) 205-3817', None, None, False, None, None, False, False, None, False, True)
# (20357, 'EUT84KYB', 'Kermit', 'Barr', 'Laredo', 'NT', 'eu@dignissimlacusAliquam.com', '(523) 809-1528', None, None, True, True, False, False, False, None, None, None)
# (20359, 'HXY50GHV', 'Sheila', 'Dickerson', 'Opelousas', 'VA', 'nulla.at@tincidunt.edu', '(406) 217-7022', None, None, None, None, None, True, None, True, True, None)
# (20362, 'QUN93ZIC', 'Ivy', 'Herring', 'Muskegon', 'WY', 'vel.faucibus.id@elitNulla.org', '(297) 813-6388', None, None, None, None, None, None, None, True, False, None)
# (20374, 'JYA56TFX', 'Tad', 'Crawford', 'Watervliet', 'PE', 'risus.Quisque.libero@dapibusrutrum.edu', '(344) 250-5575', None, False, None, None, None, False, True, None, True, True)
# (20378, 'ZAE83YKD', 'Kristen', 'Gray', 'Astoria', 'NS', 'sit.amet@lacusvestibulumlorem.edu', '(777) 290-1832', None, None, None, None, True, True, None, True, True, None)
# (20385, 'WVV38DRL', 'Savannah', 'Carrillo', 'Homer', 'AZ', 'vestibulum.lorem@nonvestibulum.edu', '(840) 976-4289', None, None, None, None, None, None, False, None, True, None)
# (20386, 'NNY42PXN', 'Hu', 'Russo', 'Ponce', 'NJ', 'Etiam@vitaeerat.org', '(956) 617-8255', None, False, False, False, False, None, None, False, True, False)
# (20388, 'GCT67NZQ', 'Uriah', 'Villarreal', 'Bartlesville', 'MD', 'id.erat@ornareelit.org', '(858) 907-5586', None, None, None, False, True, None, None, None, True, False)
# (20392, 'LAD99JVW', 'Rana', 'Martinez', 'Chicago Heights', 'ON', 'tellus.lorem@Nunc.edu', '(989) 829-5310', None, None, None, False, None, False, None, True, True, True)
# (20396, 'JVU49HHK', 'Fitzgerald', 'Stein', 'Pendleton', 'IN', 'magna.Praesent.interdum@malesuadavel.org', '(437) 780-9632', None, True, None, None, None, None, None, None, None, None)
# (20398, 'YHZ85XEG', 'Willow', 'Hicks', 'West Memphis', 'QC', 'Etiam@sociosquad.edu', '(827) 932-6453', False, None, None, False, True, True, True, True, None, None)
# (20400, 'FLB91UPT', 'Shoshana', 'Schultz', 'Muskogee', 'MD', 'et.lacinia@eleifendvitaeerat.com', '(395) 544-0934', None, False, False, None, False, None, None, None, False, None)
# (20402, 'YQR92CIU', 'Desirae', 'Velez', 'Oak Ridge', 'WY', 'semper@ultricesiaculis.com', '(829) 219-4166', None, None, False, None, None, True, True, None, True, None)
# (20403, 'UKD95BJU', 'Morgan', 'Aguilar', 'Dothan', 'YT', 'vitae.odio.sagittis@Quisquetincidunt.edu', '(738) 516-9159', None, True, False, False, None, None, True, True, False, True)
# (20404, 'AZR41JMH', 'Violet', 'Hood', 'New Iberia', 'ON', 'amet.metus@Proinvel.ca', '(719) 176-6339', None, True, None, None, None, None, True, None, None, False)
# (20410, 'YOW44YTD', 'Caesar', 'Sanders', 'Spokane', 'YT', 'Curabitur.consequat.lectus@disparturientmontes.edu', '(285) 193-1519', None, True, None, False, None, False, True, None, True, None)
# (20412, 'MUG68TDU', 'Stella', 'Mckay', 'Torrance', 'IN', 'Quisque@nunc.ca', '(695) 166-8843', None, None, None, True, True, None, False, True, True, True)
# (20414, 'HCZ89GGP', 'Elliott', 'Hendricks', 'Bay City', 'SK', 'Nulla.facilisi@Phasellus.org', '(908) 605-0515', None, False, True, True, None, None, False, False, True, False)
# (20415, 'NQD16REG', 'Sebastian', 'Norman', 'Phenix City', 'MB', 'In.nec@dictumcursusNunc.ca', '(902) 285-6212', True, True, False, None, None, False, None, None, None, None)
# (20419, 'KLX06PFO', 'Colorado', 'Patterson', 'Sierra Madre', 'AZ', 'eget.magna.Suspendisse@feugiattellus.com', '(643) 532-2853', True, True, True, None, None, True, True, False, None, None)
# (20422, 'ROE97IAX', 'Kareem', 'Payne', 'Gardner', 'AL', 'sem.egestas.blandit@orciDonecnibh.ca', '(196) 186-3231', None, True, False, None, None, True, None, True, None, False)
# (20424, 'GDF50YMP', 'Athena', 'Walsh', 'West Warwick', 'NS', 'leo.in.lobortis@acmieleifend.edu', '(668) 325-6593', None, None, None, None, False, True, True, True, None, None)
# (20429, 'EVV54PJO', 'Joseph', 'Justice', 'Santa Clara', 'CO', 'posuere@idliberoDonec.ca', '(589) 834-4394', True, False, None, True, False, None, None, None, None, None)
# (20438, 'KEY61DLQ', 'Amos', 'Colon', 'Savannah', 'BC', 'eu.dui.Cum@Duis.com', '(751) 917-4280', None, None, None, True, None, True, False, None, False, None)
# (20439, 'DPJ17CPZ', 'Tana', 'Merrill', 'Beaumont', 'ON', 'consequat@nibhDonecest.org', '(803) 795-9754', True, None, False, None, None, False, True, False, None, None)
# (20440, 'DFZ81OVX', 'Ava', 'Espinoza', 'Riverton', 'QC', 'rutrum.urna.nec@velvulputate.org', '(526) 805-3056', None, None, True, True, True, False, True, True, None, True)
# (20445, 'FWG40PUS', 'Brody', 'Sweeney', 'Thomasville', 'VT', 'est.arcu.ac@ridiculus.com', '(237) 905-0557', None, None, None, False, None, None, True, None, False, False)
# (20446, 'LDU41JMS', 'Sybill', 'Daniels', 'Gold Beach', 'DE', 'nec@luctuset.ca', '(628) 788-8251', None, None, False, False, None, False, True, None, None, None)
# (20447, 'FKA92WVO', 'Holmes', 'Warner', 'Newburyport', 'MO', 'egestas.hendrerit@ac.ca', '(366) 725-9195', None, False, True, False, False, None, None, True, None, False)
# (20448, 'MKA16NCW', 'Iris', 'Mcknight', 'Charlottesville', 'KS', 'Lorem.ipsum@ultricessitamet.com', '(488) 518-5827', None, True, None, None, None, None, None, True, None, None)
# (20450, 'WFT10SZN', 'Adrienne', 'Camacho', 'Cypress', 'AZ', 'aptent.taciti.sociosqu@sociosquadlitora.com', '(839) 374-3095', False, True, True, True, None, True, True, None, None, False)
# (20453, 'TCY80GFZ', 'Fiona', 'Barrett', 'Cape Girardeau', 'BC', 'senectus.et@Etiam.com', '(716) 491-3149', None, False, True, None, True, True, False, None, False, False)
# (20455, 'NFU01WVJ', 'Juliet', 'Sims', 'Glendale', 'MB', 'sodales.nisi@fringilla.org', '(847) 352-0468', False, True, None, False, None, None, None, True, True, False)
# (20456, 'TDB06GED', 'Tobias', 'Benson', 'Rock Island', 'MN', 'diam.nunc@sapienNunc.com', '(814) 534-4203', None, None, None, False, True, None, None, None, True, False)
# (20458, 'DIJ76XNV', 'Delilah', 'Wolfe', 'Syracuse', 'AK', 'augue.id@adlitora.ca', '(302) 726-7198', True, False, False, False, None, None, False, None, None, False)
# (20462, 'XFY06TOP', 'Rosalyn', 'Ortega', 'Bangor', 'NT', 'Nunc.ac@dolorsit.ca', '(568) 405-7291', None, False, None, None, True, None, None, True, False, True)
# (20465, 'QAZ89ADN', 'Kyle', 'Casey', 'Dalton', 'IA', 'a.magna.Lorem@nonluctus.org', '(403) 679-7287', None, None, None, None, True, True, None, True, False, None)
# (20466, 'JLQ92QRM', 'Kaitlin', 'Hines', 'Port Huron', 'SD', 'accumsan.sed.facilisis@dolor.com', '(979) 897-4934', None, False, True, False, None, False, None, None, False, None)
# (20467, 'EVC07WMR', 'David', 'Washington', 'Winnemucca', 'RI', 'ante@molestiesodales.ca', '(168) 375-3725', True, False, False, None, None, None, False, True, False, True)
# (20470, 'KQQ33PPW', 'Breanna', 'Best', 'Pullman', 'NY', 'sociis@velvulputateeu.ca', '(925) 439-7640', None, None, False, False, None, False, False, True, True, False)
# (20471, 'SDY04WUC', 'Eugenia', 'Tanner', 'McAlester', 'MD', 'lobortis.Class.aptent@vulputate.org', '(362) 324-2999', True, False, False, None, None, None, None, False, None, None)
# (20473, 'PWY79RMH', 'Jerome', 'Shelton', 'Norman', 'DE', 'metus.vitae.velit@Suspendissealiquet.ca', '(393) 451-0374', None, None, False, None, True, None, None, True, None, None)
# (20475, 'JNY85EFK', 'Hashim', 'Valencia', 'Fairbanks', 'NS', 'nunc.sed.libero@vestibulumMauris.ca', '(740) 317-3693', None, True, False, None, True, True, True, True, False, None)
# (20478, 'KAE32QCJ', 'Laith', 'Campos', 'Tonawanda', 'OH', 'fringilla.purus.mauris@magnisdisparturient.com', '(261) 554-1648', None, None, False, True, False, True, True, None, None, None)
# (20479, 'KWZ93LCB', 'Tanner', 'Wynn', 'Cohoes', 'YT', 'fringilla@Fuscedolor.org', '(445) 911-2855', True, False, False, False, None, None, False, True, None, True)
# (20480, 'TJN65RZK', 'Dai', 'Mann', 'Hornell', 'ON', 'sit@etnunc.org', '(765) 338-0114', None, None, False, None, None, None, None, None, True, None)
# (20482, 'YQW08PDE', 'Shoshana', 'Russo', 'Plano', 'SC', 'velit@consequatenim.org', '(148) 124-9236', True, False, False, True, True, False, False, None, True, None)
# (20488, 'RUJ23CND', 'Olympia', 'Lane', 'Galveston', 'ME', 'sed@Duisdignissim.edu', '(410) 867-3347', False, None, True, None, True, False, None, True, False, None)
# (20489, 'MIC39WTJ', 'Dominic', 'Knapp', 'Stockton', 'AB', 'Donec@dignissimMaecenasornare.ca', '(735) 875-5256', None, True, True, False, None, True, True, None, None, None)
# (20490, 'PRQ43FZR', 'Preston', 'Mercer', 'Biddeford', 'PA', 'quam@Craseget.org', '(632) 610-6136', None, None, True, None, None, None, None, None, None, True)
# (20492, 'WSB23YVK', 'Astra', 'Burt', 'Joliet', 'OR', 'Aenean@arcuVivamus.edu', '(154) 799-5253', False, None, None, False, None, None, False, None, None, True)
# (20493, 'DOA84AJS', 'Laith', 'Payne', 'Jacksonville', 'VT', 'at@Suspendissedui.org', '(880) 562-9559', None, None, True, None, None, True, None, None, None, None)
# (20494, 'ZBX46CJF', 'Moana', 'Franco', 'Oneida', 'KY', 'lorem@inceptos.com', '(403) 111-5436', None, False, None, None, True, False, False, True, None, None)
# (20499, 'BUV14OVI', 'Damon', 'Robertson', 'Agawam', 'NE', 'vel.sapien.imperdiet@metusvitae.org', '(758) 864-9033', None, None, True, None, False, None, True, True, None, None)
# (20500, 'CYL96WWR', 'Candace', 'Ellison', 'Beaumont', 'SK', 'velit.Pellentesque@rutrumnonhendrerit.ca', '(990) 887-6589', None, True, None, True, None, None, True, None, None, False)
# (20507, 'CWQ80DQP', 'Sylvia', 'Pope', 'New Iberia', 'AZ', 'penatibus.et.magnis@sedleoCras.com', '(461) 550-5928', None, False, False, None, False, None, False, False, True, False)
# (20508, 'JOG80IMB', 'Latifah', 'Greer', 'Cicero', 'YT', 'tempus.eu.ligula@libero.org', '(729) 981-9398', None, False, None, True, False, False, None, None, False, None)
# (20509, 'FND14HBU', 'Devin', 'Ward', 'Aliquippa', 'FL', 'mi.enim@lacusMaurisnon.ca', '(738) 851-1675', True, False, True, None, True, True, False, True, None, False)
# (20510, 'ZEH87MZK', 'Christine', 'Mccray', 'Harrisburg', 'ME', 'dui@Namligulaelit.com', '(523) 215-7790', None, True, False, None, False, None, None, None, None, None)
# (20513, 'VYA09JIF', 'Burton', 'Meyers', 'Glen Cove', 'ON', 'morbi.tristique@ac.ca', '(897) 959-8338', None, None, False, False, None, True, None, True, None, None)
# (20514, 'SEY66XKB', 'Daphne', 'Ellison', 'Georgetown', 'WA', 'Cras.dolor.dolor@tincidunttempusrisus.org', '(102) 737-5204', False, False, False, False, None, None, False, None, None, True)
# (20515, 'BQZ79SJG', 'Noel', 'Sampson', 'Rolling Hills Estates', 'SK', 'dolor.Nulla.semper@inconsectetueripsum.ca', '(314) 178-3183', None, None, None, None, True, None, False, True, None, False)
# (20516, 'XSN94HIP', 'Buffy', 'Orr', 'Geneva', 'CT', 'at@Quisque.ca', '(613) 196-8684', None, False, None, True, None, None, False, None, False, True)
# (20522, 'YEJ56XDA', 'Nathaniel', 'Barron', 'Wausau', 'NB', 'Phasellus.elit@porttitorvulputate.edu', '(949) 608-5705', None, None, True, None, False, None, None, None, True, True)
# (20527, 'RZP38UAK', 'Katell', 'Mcgee', 'Henderson', 'NT', 'porttitor.vulputate@lobortis.edu', '(289) 380-4736', False, True, True, True, None, None, True, False, True, None)
# (20528, 'BHS31UUZ', 'Caryn', 'Kelley', 'Sanford', 'TX', 'Etiam.gravida@Nam.com', '(435) 803-7216', True, True, None, None, None, None, None, True, True, True)
# (20530, 'ALY22NBQ', 'Robert', 'Patton', 'Oro Valley', 'NV', 'purus.ac.tellus@convalliserateget.edu', '(344) 827-2829', None, True, None, None, False, None, None, None, None, False)
# (20531, 'JCU13NKE', 'Rebecca', 'Hampton', 'Olympia', 'LA', 'facilisis.facilisis@bibendumullamcorperDuis.ca', '(669) 185-2863', True, True, True, None, None, True, True, None, False, True)
# (20532, 'SIM81ACA', 'Matthew', 'Howell', 'Miami', 'ON', 'Fusce.feugiat@mus.edu', '(378) 238-5346', None, None, None, None, False, False, True, None, False, False)
# (20533, 'TLY88UJF', 'Danielle', 'Avila', 'Douglas', 'ME', 'dictum.augue@adipiscing.ca', '(605) 774-9823', None, None, True, None, None, None, True, False, None, None)
# (20534, 'OFS29DEW', 'Ignacia', 'Maddox', 'Kenner', 'QC', 'penatibus@idrisus.edu', '(463) 711-5355', None, False, None, True, True, None, True, None, None, None)
# (20537, 'ZNV79UHE', 'Rashad', 'Manning', 'Cheyenne', 'FL', 'Donec@id.edu', '(873) 292-9875', None, False, None, True, True, None, None, True, None, None)
# (20539, 'CHK99ZPF', 'Mannix', 'Gross', 'Anderson', 'NU', 'eget@in.org', '(461) 747-6088', None, False, False, None, False, True, True, True, True, None)
# (20540, 'KZM14GUO', 'Blaine', 'Mcintosh', 'Seaford', 'BC', 'nisi.Mauris@liberoMorbiaccumsan.ca', '(596) 344-9219', None, False, False, None, False, False, False, False, True, True)
# (20542, 'CXQ85NJG', 'Chester', 'Knapp', 'St. Petersburg', 'NS', 'mattis.Cras.eget@ante.org', '(431) 894-9997', None, True, False, None, None, False, False, True, True, None)
# (20544, 'LYP76AQH', 'Ima', 'Calderon', 'Biddeford', 'NS', 'dolor.egestas@nulla.org', '(178) 146-6280', None, None, None, None, None, False, True, False, True, True)
# (20545, 'XML99DRH', 'Vernon', 'Nicholson', 'Rancho Palos Verdes', 'NL', 'mauris@Donec.edu', '(670) 166-8957', None, None, False, False, None, False, False, None, None, False)
# (20546, 'AJL00CYY', 'Maya', 'Mosley', 'Meadville', 'IN', 'tortor.at@odioNaminterdum.edu', '(271) 362-5959', True, False, None, True, False, False, True, None, True, None)
# (20547, 'YDF28KSV', 'Whoopi', 'Nolan', 'Hollywood', 'SK', 'dignissim@pede.org', '(203) 692-6304', False, False, True, False, True, None, True, None, None, False)
# (20548, 'QUK27RVB', 'Pandora', 'Foreman', 'Saint Cloud', 'OK', 'et@dictummi.org', '(866) 823-0175', False, False, None, False, True, False, None, True, False, False)
# (20554, 'YWR73YNZ', 'Cora', 'Perry', 'Overland Park', 'NH', 'placerat.velit@adipiscing.org', '(250) 887-9123', None, None, False, False, None, None, None, True, None, True)
# (20555, 'CLZ92RVK', 'Wang', 'Chan', 'Murray', 'MD', 'aliquet.diam.Sed@tellus.ca', '(550) 607-4093', False, None, None, None, False, None, True, None, None, None)
# (20559, 'WQT65ZIJ', 'Carlos', 'Vang', 'Manitowoc', 'WV', 'et.tristique@taciti.ca', '(718) 363-4614', None, True, None, False, True, None, False, False, None, None)
# (20560, 'RNQ91AKV', 'Chanda', 'Sullivan', 'Truth or Consequences', 'HI', 'Sed.id.risus@necmetusfacilisis.org', '(578) 740-3503', False, True, True, False, None, None, False, None, True, False)
# (20561, 'LKE18GNK', 'Genevieve', 'Stone', 'Isle of Palms', 'VT', 'In.lorem.Donec@Maurismolestie.edu', '(103) 598-4853', True, True, True, None, None, None, False, True, None, False)
# (20564, 'ZMP52RVN', 'Stewart', 'Oneal', 'International Falls', 'LA', 'nascetur.ridiculus@convallisest.edu', '(450) 854-7895', None, True, None, True, None, True, None, True, False, None)
# (20567, 'KOY61XRW', 'Rama', 'York', 'Lakewood', 'YT', 'Duis.volutpat@lacus.org', '(249) 100-5101', None, False, None, None, False, False, None, None, None, True)
# (20569, 'MDD05RVT', 'Fitzgerald', 'Stuart', 'Kearney', 'ON', 'diam.lorem@Seddiamlorem.com', '(793) 970-2432', None, None, True, None, False, False, None, None, None, None)
# (20573, 'KIA53UOT', 'Sonia', 'Adkins', 'Saint Albans', 'NS', 'volutpat.nunc.sit@utpharetra.com', '(991) 624-6250', None, None, True, None, None, False, False, None, True, None)
# (20579, 'DCH45GCJ', 'Zena', 'Ochoa', 'Sheridan', 'SK', 'nec.ante@at.ca', '(614) 867-6889', None, None, True, True, True, None, None, None, True, True)
# (20585, 'RXZ80KEC', 'Velma', 'Poole', 'Clairton', 'ON', 'luctus.aliquet.odio@egetvarius.org', '(434) 116-5062', True, True, True, None, False, False, False, None, None, None)
# (20586, 'KUK49CAC', 'Noah', 'Frazier', 'Troy', 'IN', 'vitae@fermentumfermentum.edu', '(327) 491-7538', False, True, True, True, True, None, False, None, None, None)
# (20589, 'YRJ18LKD', 'Kevin', 'Fields', 'Truth or Consequences', 'FL', 'volutpat@orci.edu', '(510) 803-8078', None, True, True, None, True, True, True, False, None, False)
# (20590, 'JRK17TBU', 'Kathleen', 'Solomon', 'Sioux Falls', 'NJ', 'ultrices@molestie.ca', '(874) 562-1630', None, False, True, True, None, None, None, False, True, False)
# (20594, 'GJG60NLA', 'Wilma', 'Townsend', 'Eau Claire', 'KS', 'lacus@MaurisnullaInteger.edu', '(345) 899-2548', False, None, False, False, None, None, None, None, None, False)
# (20596, 'NPU35HGX', 'Alfonso', 'Ayers', 'Akron', 'BC', 'parturient@vitaerisus.com', '(670) 188-2454', None, False, None, None, None, False, False, None, False, None)
# (20598, 'PJF78JHA', 'Kaitlin', 'Woods', 'Lancaster', 'SK', 'montes.nascetur@eratVivamusnisi.com', '(895) 561-5443', True, None, False, None, None, True, False, False, False, True)
# (20599, 'DSJ63OGS', 'Yeo', 'Marks', 'Malden', 'MS', 'amet.ante.Vivamus@acliberonec.edu', '(829) 412-9483', None, False, None, False, True, False, None, None, True, True)
# (20602, 'GOZ32FFO', 'Uma', 'Moon', 'Manchester', 'MS', 'ut.nisi.a@anteMaecenasmi.ca', '(392) 863-2434', True, None, None, False, True, True, None, None, None, False)
# (20603, 'ETQ93AGU', 'Hermione', 'Pena', 'Hutchinson', 'MA', 'id.blandit@Mauris.ca', '(197) 601-7966', None, None, True, False, False, True, None, True, True, True)
# (20604, 'RUH28LYT', 'Beau', 'Miles', 'La Habra', 'MS', 'magnis.dis.parturient@Maecenasmalesuadafringilla.com', '(342) 344-8924', False, False, None, False, None, True, False, False, False, False)
# (20605, 'NHK77WPT', 'Barclay', 'Andrews', 'Morgan City', 'SK', 'eu.augue.porttitor@estacmattis.org', '(916) 680-1374', None, None, False, None, None, None, None, False, True, True)
# (20607, 'ERK66VXS', 'Chelsea', 'Peterson', 'Huntington', 'WA', 'semper.Nam@sagittisDuisgravida.com', '(694) 589-9072', False, True, None, None, True, False, True, None, True, None)
# (20609, 'QID91CNF', 'Sebastian', 'Valenzuela', 'Port Washington', 'SC', 'in.lobortis@penatibusetmagnis.com', '(312) 117-5081', None, True, True, False, None, None, False, None, False, True)
# (20616, 'ERP77PHT', 'Macaulay', 'Cannon', 'Reading', 'NT', 'purus@velit.com', '(695) 880-5587', None, True, True, None, None, None, None, None, None, True)
# (20617, 'VSK65MED', 'Elton', 'Velez', 'Farmington', 'NB', 'Fusce.mi.lorem@sitametluctus.com', '(965) 974-1282', None, False, False, True, None, True, None, True, None, True)
# (20618, 'LLI42UNM', 'Lydia', 'Sanchez', 'Lynn', 'NB', 'Nunc.quis@fringillaporttitor.org', '(986) 793-5860', False, None, False, None, False, None, None, True, False, True)
# (20619, 'BKE73OGD', 'Cadman', 'Fleming', 'Rancho Cordova', 'RI', 'sociis@sed.edu', '(853) 184-5436', None, None, None, True, True, None, None, None, None, True)
# (20623, 'GUI32XZX', 'Harper', 'Bridges', 'La Palma', 'NS', 'elementum.at.egestas@lacinia.com', '(311) 993-5418', None, False, None, None, None, None, None, True, True, False)
# ...
# (49351, 'MBL97VRD', 'Gavin', 'Christian', 'Boise', 'KY', 'montes.nascetur.ridiculus@Maurisvestibulum.edu', '(502) 492-9820', None, None, None, False, None, None, True, None, None, True)
# (49353, 'MTS27RMB', 'Uriel', 'Shannon', 'Eden Prairie', 'ON', 'enim@Etiam.ca', '(838) 673-9861', None, True, True, None, False, None, True, None, True, True)
# (49354, 'JFQ90YWV', 'Laurel', 'Workman', 'Yakima', 'NH', 'massa@rhoncusDonec.org', '(398) 298-4169', None, None, None, False, None, None, None, False, None, None)
# (49357, 'ISM89NWN', 'Kennan', 'Fernandez', 'Abilene', 'VT', 'ante.Nunc@ipsumPhasellus.edu', '(969) 539-5804', True, False, True, False, None, False, True, False, None, None)
# (49359, 'NEM46EDH', 'Adara', 'Delgado', 'Delta Junction', 'BC', 'Duis.volutpat@sed.com', '(588) 947-2170', None, True, False, False, True, None, True, False, False, False)
# (49360, 'RIE68ZXZ', 'Natalie', 'Walter', 'Lawndale', 'QC', 'est.tempor@posuerecubilia.org', '(208) 998-8470', None, None, None, None, None, None, True, False, None, None)
# (49365, 'YCW67IPP', 'Abra', 'Patterson', 'Corvallis', 'HI', 'et.magnis@pedenecante.ca', '(236) 456-4331', False, True, False, None, None, None, None, True, True, None)
# (49367, 'HRP92XNI', 'Reuben', 'Ray', 'Oil City', 'VT', 'ullamcorper.nisl@semeget.com', '(144) 763-2791', None, False, None, True, None, True, True, None, True, False)
# (49378, 'PYK28ZEQ', 'Heidi', 'Raymond', 'Weirton', 'PE', 'dolor.sit@porttitorvulputateposuere.com', '(712) 261-9020', None, None, False, False, False, True, True, False, True, None)
# (49384, 'LRX59YIG', 'Paula', 'Caldwell', 'Attleboro', 'AB', 'in.molestie.tortor@dictum.com', '(672) 819-2952', True, None, None, True, None, False, None, False, None, None)
# (49385, 'FXB00AIA', 'Kaitlin', 'Mathews', 'Livonia', 'IL', 'Proin.vel.nisl@enimcommodohendrerit.edu', '(298) 636-1497', True, None, True, False, False, False, False, True, True, None)
# (49386, 'RBP23GKU', 'Chelsea', 'Carey', 'Hudson', 'CA', 'Fusce.aliquet.magna@enimEtiam.com', '(182) 143-7993', None, None, None, True, None, True, True, False, False, False)
# (49389, 'ZCE91UYA', 'Tamara', 'Steele', 'Hampton', 'NS', 'faucibus.orci@elit.edu', '(381) 678-4961', None, None, None, None, None, True, True, None, False, True)
# (49391, 'NQD19BXM', 'Judith', 'Weiss', 'Weymouth', 'NT', 'nibh@Mauris.edu', '(535) 580-0974', True, None, None, False, False, None, True, None, None, None)
# (49393, 'NFC83SJJ', 'Holly', 'Bowman', 'Kona', 'NE', 'consequat.purus.Maecenas@diamPellentesquehabitant.edu', '(786) 679-8717', False, False, None, None, False, True, False, True, None, False)
# (49395, 'SAB69LMK', 'Carol', 'Ayala', 'Lancaster', 'WI', 'sem.ut@eratvolutpat.org', '(240) 283-4962', True, True, True, None, None, None, None, True, False, None)
# (49396, 'IQT45CXN', 'Odette', 'Campos', 'Fernley', 'MB', 'parturient.montes.nascetur@Quisqueimperdieterat.org', '(997) 648-1273', None, None, None, None, None, None, None, None, False, True)
# (49398, 'BUO70FXH', 'Patrick', 'Figueroa', 'Half Moon Bay', 'SK', 'montes.nascetur@Donecest.ca', '(185) 503-8834', None, None, None, None, False, None, False, None, True, False)
# (49403, 'NLW65RQT', 'Unity', 'Baldwin', 'Long Beach', 'VT', 'ipsum.Donec.sollicitudin@hendrerit.edu', '(445) 716-3743', None, True, False, False, True, None, False, None, None, None)
# (49404, 'VSE48UVP', 'Chester', 'Castro', 'San Luis Obispo', 'NL', 'nibh@aarcu.org', '(658) 159-3338', True, None, None, True, False, None, None, True, True, False)
# (49405, 'DGD17COC', 'Isaiah', 'Gross', 'Owensboro', 'WY', 'non.cursus@neque.edu', '(851) 392-2698', None, False, None, None, None, None, None, None, None, None)
# (49407, 'RQR03DMU', 'Rigel', 'Cardenas', 'Longview', 'SD', 'Duis@aliquet.com', '(784) 938-6980', None, True, False, False, True, None, None, None, True, False)
# (49408, 'FNU18QVW', 'Jade', 'Valenzuela', 'Baton Rouge', 'NC', 'sem.eget@mi.org', '(900) 452-8013', True, None, False, True, None, False, False, False, True, False)
# (49416, 'SXA15PXM', 'Jasmine', 'Mendoza', 'Livonia', 'AB', 'Aliquam.rutrum.lorem@loremvehiculaet.edu', '(588) 272-6780', None, None, True, True, None, None, None, None, None, None)
# (49418, 'RPY82WAW', 'Burton', 'Cline', 'Salisbury', 'SC', 'Ut@libero.org', '(833) 520-0951', None, True, True, None, True, True, True, None, False, False)
# (49422, 'UDU59RYO', 'Garrett', 'Foreman', 'Cedarburg', 'NJ', 'odio.Etiam.ligula@nuncInat.org', '(445) 151-6114', None, None, False, None, True, True, None, True, None, True)
# (49426, 'EIU45LXM', 'Maite', 'Witt', 'Tyler', 'MB', 'arcu@Aenean.org', '(401) 980-1483', True, None, True, None, None, False, False, None, True, False)
# (49428, 'UDV31VDM', 'Jillian', 'Hurley', 'Laguna Beach', 'NS', 'purus@sapienAenean.edu', '(756) 131-4159', None, None, None, None, True, False, None, False, None, False)
# (49431, 'GOS18UNK', 'Jordan', 'Wolf', 'Huntsville', 'YT', 'Aliquam.rutrum.lorem@Duiselementumdui.org', '(984) 741-9888', None, True, None, True, None, True, None, False, True, True)
# (49436, 'MCM47SHO', 'Fallon', 'Finch', 'Gainesville', 'PE', 'Vivamus.nibh.dolor@aliquetmolestie.ca', '(237) 513-5390', None, True, True, None, None, False, None, False, False, False)
# (49437, 'NXD90MMI', 'Jakeem', 'Le', 'Bloomington', 'AZ', 'nisl@tellusfaucibus.edu', '(727) 363-9682', None, None, False, False, None, True, True, None, False, True)
# (49438, 'VCR06AAI', 'Tamara', 'Durham', 'Lockport', 'AK', 'primis.in@Maecenasmalesuada.ca', '(176) 663-0911', None, True, None, False, True, None, False, False, None, True)
# (49439, 'QKO20XJZ', 'Alice', 'Kent', 'Quincy', 'MN', 'dapibus.id.blandit@massa.org', '(828) 202-1326', False, None, False, True, None, None, True, True, None, None)
# (49440, 'ROW85BZX', 'Frances', 'Olson', 'Sunnyvale', 'NU', 'non@ideratEtiam.org', '(270) 459-1239', True, None, None, None, True, None, None, True, False, False)
# (49441, 'RHK08JEE', 'Rae', 'Branch', 'Rhinelander', 'NC', 'non.arcu@Sedcongue.org', '(346) 767-4159', True, False, True, True, None, True, True, False, False, False)
# (49442, 'MGW28RRZ', 'Cora', 'Mcgee', 'Northampton', 'GA', 'malesuada.vel@quamvel.org', '(576) 342-8591', None, False, True, False, True, None, None, True, None, True)
# (49444, 'NIJ52SIX', 'Chanda', 'Gonzales', 'Kingston', 'AZ', 'natoque.penatibus@semper.edu', '(465) 714-9896', None, True, False, None, True, None, None, None, None, False)
# (49449, 'FTG48WCM', 'Tashya', 'Pittman', 'Beverly', 'IL', 'ipsum.Suspendisse@Aeneaneuismodmauris.ca', '(248) 965-7590', None, False, True, None, None, False, True, None, True, None)
# (49450, 'CPJ02XTV', 'Reed', 'Sawyer', 'Arcadia', 'CO', 'elit@NullaaliquetProin.org', '(240) 508-5055', None, False, False, None, False, None, None, False, None, True)
# (49459, 'POT86QZR', 'Cedric', 'Washington', 'Moscow', 'NT', 'ut.quam.vel@egestas.edu', '(421) 725-2310', None, True, None, None, None, None, False, True, None, False)
# (49460, 'GVO90DEL', 'Echo', 'Cortez', 'Mesa', 'NL', 'iaculis@etmagnis.org', '(711) 301-1840', None, None, None, False, True, False, None, False, False, False)
# (49462, 'ATN88VEG', 'Shelley', 'Norman', 'Keene', 'WI', 'sollicitudin.orci@felisullamcorper.edu', '(641) 867-5320', None, False, True, None, None, False, None, None, None, None)
# (49463, 'HTO14ISU', 'Lance', 'Salas', 'Woodruff', 'WA', 'Aliquam.tincidunt.nunc@metusInnec.edu', '(719) 267-1598', None, True, None, None, True, True, None, False, False, None)
# (49465, 'MWB08AKA', 'Lester', 'Bradshaw', 'Hoboken', 'SK', 'vulputate.velit.eu@Aeneaneuismodmauris.edu', '(306) 154-7884', True, True, True, False, False, None, None, None, None, None)
# (49466, 'NGZ58LGQ', 'Desirae', 'Moss', 'Monongahela', 'SK', 'turpis.nec@metus.ca', '(764) 898-0992', None, None, None, True, True, None, True, False, None, False)
# (49468, 'PVU44DDM', 'Quinn', 'Roberson', 'Independence', 'CT', 'accumsan@afelisullamcorper.com', '(196) 925-8621', True, False, None, None, None, None, False, False, None, None)
# (49469, 'OIH46VHH', 'Brenden', 'Holt', 'Baytown', 'FL', 'dui.semper.et@tempordiamdictum.org', '(226) 108-8003', None, True, None, True, True, None, False, None, False, None)
# (49470, 'HRZ37VEU', 'Teegan', 'Lott', 'Derby', 'NU', 'convallis.in@variusNam.org', '(236) 989-3164', True, None, None, False, True, True, None, True, None, None)
# (49473, 'KFI51BSM', 'Theodore', 'Benjamin', 'St. Marys', 'MT', 'Curabitur@arcuCurabiturut.edu', '(451) 411-6016', None, None, False, False, True, None, None, None, False, True)
# (49474, 'LFB73DLJ', 'Donna', 'Britt', 'Danbury', 'PE', 'nunc.interdum@utlacus.edu', '(214) 833-8518', None, None, None, None, None, False, None, True, False, None)
# (49476, 'NUW41GXF', 'Cruz', 'Leach', 'Kearney', 'MN', 'sit.amet@lacinia.org', '(554) 284-5795', None, None, None, None, None, True, None, False, True, False)
# (49481, 'WOH38ALN', 'Matthew', 'Franklin', 'Forrest City', 'NS', 'Maecenas@facilisisSuspendisse.org', '(640) 126-0671', None, True, None, True, False, None, False, False, False, False)
# (49483, 'JPS56OGS', 'Dane', 'Ball', 'Plattsburgh', 'NL', 'eget.magna.Suspendisse@Suspendisseseddolor.org', '(294) 672-9442', True, None, None, None, False, None, True, True, True, None)
# (49485, 'PJM73KLX', 'Sydnee', 'Park', 'Liberal', 'NT', 'sed.sapien@velnisl.org', '(279) 913-1302', None, True, False, None, None, True, False, False, None, False)
# (49487, 'QGL64RKW', 'Fay', 'Gentry', 'Burbank', 'ND', 'pharetra.Quisque.ac@turpisAliquam.com', '(393) 557-1022', True, None, True, None, None, None, None, None, None, True)
# (49488, 'FNE70YWE', 'Craig', 'Campos', 'Atlanta', 'BC', 'neque.venenatis@lectusrutrumurna.org', '(289) 629-1631', None, False, None, None, None, None, False, None, True, False)
# (49489, 'AML67LVK', 'Rebekah', 'Woods', 'Norwich', 'YT', 'in.molestie@Etiam.com', '(315) 387-4054', False, None, None, True, None, True, False, None, True, False)
# (49492, 'HBG07PGW', 'Phyllis', 'Cohen', 'Dodge City', 'NB', 'Etiam.ligula@Nam.ca', '(918) 881-6600', False, False, None, None, None, True, None, True, None, None)
# (49494, 'UJF16YLO', 'Quynn', 'Osborne', 'Syracuse', 'VA', 'imperdiet.non.vestibulum@lectus.org', '(406) 515-4765', None, None, None, True, None, False, True, None, False, None)
# (49495, 'KJT95IJI', 'Wesley', 'Vega', 'Dearborn', 'NB', 'semper.tellus.id@euismod.org', '(763) 138-0731', None, None, None, True, None, True, False, None, False, None)
# (49496, 'CRV19RFT', 'April', 'Gill', 'Sunnyvale', 'NS', 'a.felis.ullamcorper@mienim.edu', '(780) 360-3397', None, False, None, False, False, True, False, False, False, False)
# (49498, 'UVH81ZYU', 'Kaitlin', 'Hansen', 'Yuma', 'WA', 'nibh.dolor.nonummy@tellusAenean.ca', '(632) 480-0033', None, True, None, False, False, None, None, None, None, None)
# (49501, 'FAC20WZY', 'Lilah', 'Cantrell', 'Hannibal', 'AK', 'Nunc.sollicitudin@iaculislacuspede.com', '(649) 985-9082', None, None, False, None, None, False, True, None, False, None)
# (49506, 'CNL10ERQ', 'Neville', 'Torres', 'St. George', 'BC', 'Suspendisse.sed.dolor@erat.com', '(617) 334-3815', None, True, True, False, False, None, None, False, None, False)
# (49511, 'ZOS62YAF', 'Meredith', 'Wagner', 'Lowell', 'NC', 'Phasellus@augueid.edu', '(144) 868-8873', None, False, False, None, None, True, None, True, False, False)
# (49513, 'BPG73JHP', 'Dorian', 'Bonner', 'Palo Alto', 'HI', 'justo.sit.amet@enim.edu', '(158) 223-2145', None, False, None, True, False, True, None, False, True, True)
# (49516, 'JKA59NAL', 'Martin', 'West', 'Seaford', 'CT', 'vulputate.posuere.vulputate@mauris.com', '(897) 777-9567', None, True, True, None, None, True, None, False, False, None)
# (49517, 'XBT68NNJ', 'Caleb', 'Ford', 'Rolla', 'MN', 'Proin@convallis.ca', '(454) 362-2793', False, True, True, None, None, True, None, None, None, False)
# (49518, 'ANO31VPY', 'Rhonda', 'Weiss', 'Santa Clara', 'ID', 'vitae.purus@ligulatortor.org', '(613) 564-8175', None, False, True, None, False, None, True, None, True, None)
# (49520, 'KQH22IHE', 'Cleo', 'Baxter', 'Fallon', 'CO', 'massa.Vestibulum@Nunc.com', '(879) 672-1012', True, False, True, False, True, None, None, None, None, None)
# (49521, 'BAO67UVU', 'Ursula', 'Bray', 'Rehoboth Beach', 'YT', 'ultricies@ipsum.ca', '(260) 494-3666', None, None, None, False, True, None, None, True, True, None)
# (49522, 'XDQ20BRU', 'Neil', 'French', 'Saginaw', 'AL', 'rutrum.lorem.ac@duisemper.org', '(187) 338-9956', None, True, True, True, None, False, None, None, None, None)
# (49523, 'QJN96IWQ', 'Shay', 'Mann', 'Bossier City', 'DC', 'eget.metus@egestasligula.org', '(884) 223-1357', False, None, None, None, None, True, True, None, True, False)
# (49524, 'NTY69GUI', 'Rhona', 'Lang', 'Chesapeake', 'BC', 'metus.sit.amet@eu.com', '(609) 397-5461', None, None, None, None, None, True, None, False, False, None)
# (49528, 'PXG32JDK', 'Kevin', 'Dale', 'Hudson', 'MS', 'adipiscing.elit@dapibusligula.com', '(228) 657-7296', None, True, False, True, True, True, None, True, None, None)
# (49529, 'GHQ88JQB', 'Gay', 'Francis', 'Boston', 'PE', 'turpis.Aliquam@quis.ca', '(799) 614-1883', True, None, None, False, None, None, True, None, None, None)
# (49531, 'DUS43IXZ', 'Aurelia', 'Morris', 'Bellflower', 'KS', 'id.ante.Nunc@magnaPhasellus.org', '(626) 104-7026', None, False, None, None, None, False, None, False, False, False)
# (49533, 'QRD07GFG', 'Adena', 'Kaufman', 'Lowell', 'NJ', 'Cras.eget.nisi@sit.edu', '(408) 985-2547', None, None, None, True, None, None, None, True, None, None)
# (49534, 'AIF91VER', 'Dustin', 'Thornton', 'Claremore', 'SK', 'dui.Cum@maurissapien.edu', '(653) 459-9525', True, None, None, True, True, False, True, None, None, True)
# (49535, 'MNZ81ZVS', 'Cole', 'Gray', 'Lowell', 'VT', 'velit.dui@semNullainterdum.ca', '(805) 982-4172', None, False, True, None, None, True, None, True, None, None)
# (49537, 'GPJ50YLK', 'Lynn', 'Terrell', 'Stanton', 'NL', 'posuere.vulputate@Duis.ca', '(940) 119-2942', None, None, None, None, True, None, None, True, None, True)
# (49540, 'CJH01VZU', 'Flavia', 'Moses', 'Concord', 'NB', 'volutpat.ornare@Donec.org', '(242) 544-2654', None, None, True, None, None, None, True, False, None, None)
# (49541, 'KRB80MCR', 'Amal', 'Marshall', 'San Rafael', 'NB', 'scelerisque.scelerisque.dui@enimconsequatpurus.com', '(586) 273-1043', None, False, False, True, True, None, None, True, None, None)
# (49542, 'EYD26NKU', 'Wesley', 'Riddle', 'Atwater', 'NE', 'semper.auctor@risusquisdiam.ca', '(603) 217-8196', None, None, None, None, False, None, None, True, True, None)
# (49543, 'GCH32AGJ', 'Yasir', 'Stuart', 'Monterey', 'ND', 'feugiat@turpisAliquam.edu', '(225) 852-4220', None, None, True, True, None, True, False, None, None, None)
# (49546, 'CQB72DXC', 'Sopoline', 'Hobbs', 'Cairo', 'WV', 'nunc.In@ultricesDuisvolutpat.org', '(209) 211-8469', None, None, False, None, None, None, None, None, True, False)
# (49547, 'EVK29NEL', 'Cedric', 'Brady', 'Sierra Vista', 'CO', 'ut@velit.com', '(545) 985-2742', False, None, False, True, False, True, None, False, True, False)
# (49549, 'BYH71ABU', 'Molly', 'Barlow', 'Cranston', 'DC', 'Nulla.tincidunt.neque@necluctus.edu', '(912) 875-5555', None, None, None, None, None, None, True, None, None, None)
# (49551, 'KEO07PBB', 'Marsden', 'Roth', 'Orem', 'ID', 'Nulla@necligulaconsectetuer.edu', '(887) 795-1973', True, True, False, None, None, False, None, True, None, False)
# (49556, 'TMD26ENC', 'Wynter', 'Cummings', 'Leominster', 'NB', 'lorem.auctor.quis@erat.com', '(672) 450-3607', None, None, False, False, None, None, True, None, None, True)
# (49557, 'QQU01WKW', 'Xerxes', 'Burris', 'Steubenville', 'MB', 'Class.aptent@purussapien.com', '(758) 527-5796', None, None, None, None, None, False, None, True, False, False)
# (49558, 'WJA35TXK', 'Orla', 'Kidd', 'Burlington', 'NB', 'magna.Cras@risus.org', '(495) 739-2163', None, None, True, False, None, False, True, False, False, False)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
try:
  conn.close()
except psycopg2.Error as e:
  print(e)

# %%
redshift.delete_cluster(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER, SkipFinalClusterSnapshot=True)
